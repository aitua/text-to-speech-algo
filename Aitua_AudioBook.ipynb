# %% [markdown]
# # Create an Audiobook from a PDF
# ## This task tests your ability to apply Text to Speech conversion and Extraction of Text from PDF files in the creation of an audiobook from a PDF file

# %% [markdown]
# ### Steps
# - Extract text from PDF file
# - Clean the text
# - Convert the text into speech
# - Save the speech
# - Play the speech

# %% [markdown]
# ## 1. Extract text from PDF
# - Use PyPDF2

# %% [markdown]
# ### Install the library

# %%
 ! pip install PyPDF2

# %% [markdown]
# ### Import the library

# %%
import PyPDF2

# %% [markdown]
# ### Extract the text

# %%
pdf_path = '/content/Sanofi_Recorded_Interview_Script.pdf'
pdf_text = ""

with open(pdf_path, 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    for page_num in range(len(reader.pages)):
        page = reader.pages[page_num]
        pdf_text += page.extract_text()

# You can print the first few characters to verify extraction
# print(pdf_text[:500])

# %% [markdown]
# ### Print the extracted text

# %%
print(pdf_text)
# Out:
# “My name is Aitua, and From my research, I understand that Sanofi’s mission is to chase the
# miracles of science to improve people’s lives, and the Toronto hub is a key part of bringing data, AI,
# and digital health together to support medicines in chronic disease, immunology, and general
# medicines. I also saw that this role sits in the Data Science and Applied AI/EDGE environment,
# which is focused on using advanced analytics and machine learning to accelerate access and
# improve patient outcomes.
# That combination of healthcare impact plus AI is exactly where I want to grow. I’m currently in the
# Applied AI Solutions
# Development program at George Brown, so I’ve been building end ■to■end solutions — from data
# acquisition and cleaning, to feature engineering, model training, and dashboarding — and I want to
# apply that in a real health context, not just in school projects. During the co ■op, I see myself
# ...

# %% [markdown]
# ## 2. Convert the Text into Speech
# - Use **pyttsx3** OR **gTTS**

# %% [markdown]
# ### Install the library

# %%
# !pip install pyttsx3 gTTS

# %% [markdown]
# ### Import the library

# %%
from gtts import gTTS
from IPython.display import Audio

# %% [markdown]
# ### Initialize a Speaker object

# %% [markdown]
# ### Convert the text

# %%
tts = gTTS(text=pdf_text, lang='en')
output_audio_path = 'audiobook.mp3'
tts.save(output_audio_path)

# %% [markdown]
# ### Save the audio

# %%
print(f"Audiobook saved to {output_audio_path}")
# Out:
# Audiobook saved to audiobook.mp3

# %%
Audio(output_audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
